# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
air_df=pd.read_excel('/content/Data_Train.xlsx')
air_df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
air_df.shape
# Out:
# (10683, 11)

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
air_df['Date']=air_df['Date_of_Journey'].str.split('/').str[0]
air_df['Month']=air_df['Date_of_Journey'].str.split('/').str[1]
air_df['Year']=air_df['Date_of_Journey'].str.split('/').str[2]

# %%
air_df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    1
#
#   Month  Year
# 0    03  2019
# 1    05  2019

# %%
air_df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price Date Month  Year
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897   24    03  2019
# 1         13:15   7h 25m     2 stops         No info   7662    1    05  2019

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10683 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10682 non-null  object
#  8   Additional_Info  10683 non-null  object
#  9   Price            10683 non-null  int64
#  10  Date             10683 non-null  object
#  11  Month            10683 non-null  object
#  12  Year             10683 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 1.1+ MB

# %%
air_df['Date']=air_df['Date'].astype(int)
air_df['Month']=air_df['Month'].astype(int)
air_df['Year']=air_df['Year'].astype(int)

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10683 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10682 non-null  object
#  8   Additional_Info  10683 non-null  object
#  9   Price            10683 non-null  int64
#  10  Date             10683 non-null  int64
#  11  Month            10683 non-null  int64
#  12  Year             10683 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 1.1+ MB

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  Year
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897    24      3  2019
# 1         13:15   7h 25m     2 stops         No info   7662     1      5  2019

# %%
## Handling Arrival timme
air_df['Arrival_Hour']=air_df['Arrival_Time'].str.split(':').str[0]
air_df['Arrival_Minute']=air_df['Arrival_Time'].str.split(':').str[1]

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897    24      3
# 1         13:15   7h 25m     2 stops         No info   7662     1      5
#
#    Year Arrival_Hour Arrival_Minute
# 0  2019           01      10 22 Mar
# 1  2019           13             15

# %%
air_df['Arrival_Min']=air_df['Arrival_Minute'].str.split(' ').str[0]

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897    24      3
# 1         13:15   7h 25m     2 stops         No info   7662     1      5
#
#    Year Arrival_Hour Arrival_Minute Arrival_Min
# 0  2019           01      10 22 Mar          10
# 1  2019           13             15          15

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897    24      3
# 1         13:15   7h 25m     2 stops         No info   7662     1      5
#
#    Year Arrival_Hour Arrival_Minute Arrival_Min
# 0  2019           01      10 22 Mar          10
# 1  2019           13             15          15

# %%
air_df.drop('Arrival_Minute',axis=1,inplace=True)

# %%
air_df.drop('Arrival_Time',axis=1,inplace=True)

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Duration         10683 non-null  object
#  6   Total_Stops      10682 non-null  object
#  7   Additional_Info  10683 non-null  object
#  8   Price            10683 non-null  int64
#  9   Date             10683 non-null  int64
#  10  Month            10683 non-null  int64
#  11  Year             10683 non-null  int64
#  12  Arrival_Hour     10683 non-null  object
#  13  Arrival_Min      10683 non-null  object
# dtypes: int64(4), object(10)
# memory usage: 1.1+ MB

# %%
 air_df['Arrival_Hour']=air_df['Arrival_Hour'].astype(int)
 air_df['Arrival_Min']=air_df['Arrival_Min'].astype(int)

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Duration         10683 non-null  object
#  6   Total_Stops      10682 non-null  object
#  7   Additional_Info  10683 non-null  object
#  8   Price            10683 non-null  int64
#  9   Date             10683 non-null  int64
#  10  Month            10683 non-null  int64
#  11  Year             10683 non-null  int64
#  12  Arrival_Hour     10683 non-null  int64
#  13  Arrival_Min      10683 non-null  int64
# dtypes: int64(6), object(8)
# memory usage: 1.1+ MB

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
#
#   Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_Hour  \
# 0    non-stop         No info   3897    24      3  2019             1
# 1     2 stops         No info   7662     1      5  2019            13
#
#    Arrival_Min
# 0           10
# 1           15

# %%
# Now handling Dep_time

# %%
air_df['Dep_Hour']=air_df['Dep_Time'].str.split(':').str[0]
air_df['Dep_Min']=air_df['Dep_Time'].str.split(':').str[1]

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
#
#   Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_Hour  \
# 0    non-stop         No info   3897    24      3  2019             1
# 1     2 stops         No info   7662     1      5  2019            13
#
#    Arrival_Min Dep_Hour Dep_Min
# 0           10       22      20
# 1           15       05      50

# %%
air_df.drop('Dep_Time',axis=1,inplace=True)

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination                  Route Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
#
#   Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_Hour  \
# 0    non-stop         No info   3897    24      3  2019             1
# 1     2 stops         No info   7662     1      5  2019            13
#
#    Arrival_Min Dep_Hour Dep_Min
# 0           10       22      20
# 1           15       05      50

# %%
air_df['Dep_Hour']=air_df['Dep_Hour'].astype(int)
air_df['Dep_Min']=air_df['Dep_Min'].astype(int)

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Duration         10683 non-null  object
#  5   Total_Stops      10682 non-null  object
#  6   Additional_Info  10683 non-null  object
#  7   Price            10683 non-null  int64
#  8   Date             10683 non-null  int64
#  9   Month            10683 non-null  int64
#  10  Year             10683 non-null  int64
#  11  Arrival_Hour     10683 non-null  int64
#  12  Arrival_Min      10683 non-null  int64
#  13  Dep_Hour         10683 non-null  int64
#  14  Dep_Min          10683 non-null  int64
# dtypes: int64(8), object(7)
# memory usage: 1.2+ MB

# %%
# Now handling Total_stops
air_df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
air_df['Total_Stops']=air_df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':5})

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination                  Route Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
#
#    Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_Hour  \
# 0          0.0         No info   3897    24      3  2019             1
# 1          2.0         No info   7662     1      5  2019            13
#
#    Arrival_Min  Dep_Hour  Dep_Min
# 0           10        22       20
# 1           15         5       50

# %%
air_df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              1
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# Date               0
# Month              0
# Year               0
# Arrival_Hour       0
# Arrival_Min        0
# Dep_Hour           0
# Dep_Min            0
# dtype: int64

# %%
air_df.drop('Route',axis=1,inplace=True)

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0     IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1  Air India   Kolkata    Banglore   7h 25m          2.0         No info
#
#    Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min
# 0   3897    24      3  2019             1           10        22       20
# 1   7662     1      5  2019            13           15         5       50

# %%
air_df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
# Now Handlinf Duration column

air_df['Duration_Hour']=air_df['Duration'].str.split(' ').str[0]
air_df['Duration_Minutes']=air_df['Duration'].str.split(' ').str[1]

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0     IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1  Air India   Kolkata    Banglore   7h 25m          2.0         No info
#
#    Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min  \
# 0   3897    24      3  2019             1           10        22       20
# 1   7662     1      5  2019            13           15         5       50
#
#   Duration_Hour Duration_Minutes
# 0            2h              50m
# 1            7h              25m

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0     IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1  Air India   Kolkata    Banglore   7h 25m          2.0         No info
#
#    Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min  \
# 0   3897    24      3  2019             1           10        22       20
# 1   7662     1      5  2019            13           15         5       50
#
#   Duration_Hour Duration_Minutes
# 0            2h              50m
# 1            7h              25m

# %%
air_df['Duration_hr']=air_df['Duration_Hour'].str.split('h').str[0]

# %%
air_df['Duration_min']=air_df['Duration_Minutes'].str.split('m').str[0]

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0     IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1  Air India   Kolkata    Banglore   7h 25m          2.0         No info
#
#    Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min  \
# 0   3897    24      3  2019             1           10        22       20
# 1   7662     1      5  2019            13           15         5       50
#
#   Duration_Hour Duration_Minutes Duration_hr Duration_min
# 0            2h              50m           2           50
# 1            7h              25m           7           25

# %%
air_df.drop('Duration_Hour',axis=1,inplace=True)
air_df.drop('Duration_Minutes',axis=1,inplace=True)

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0     IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1  Air India   Kolkata    Banglore   7h 25m          2.0         No info
#
#    Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min  \
# 0   3897    24      3  2019             1           10        22       20
# 1   7662     1      5  2019            13           15         5       50
#
#   Duration_hr Duration_min
# 0           2           50
# 1           7           25

# %%
air_df.drop('Duration',axis=1,inplace=True)

# %%
air_df.head(2)
# Out:
#      Airline    Source Destination  Total_Stops Additional_Info  Price  Date  \
# 0     IndiGo  Banglore   New Delhi          0.0         No info   3897    24
# 1  Air India   Kolkata    Banglore          2.0         No info   7662     1
#
#    Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min Duration_hr  \
# 0      3  2019             1           10        22       20           2
# 1      5  2019            13           15         5       50           7
#
#   Duration_min
# 0           50
# 1           25

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Total_Stops      10682 non-null  float64
#  4   Additional_Info  10683 non-null  object
#  5   Price            10683 non-null  int64
#  6   Date             10683 non-null  int64
#  7   Month            10683 non-null  int64
#  8   Year             10683 non-null  int64
#  9   Arrival_Hour     10683 non-null  int64
#  10  Arrival_Min      10683 non-null  int64
#  11  Dep_Hour         10683 non-null  int64
#  12  Dep_Min          10683 non-null  int64
#  13  Duration_hr      10683 non-null  object
#  14  Duration_min     9651 non-null   object
# dtypes: float64(1), int64(8), object(6)
# memory usage: 1.2+ MB

# %%
air_df.head()
# Out:
#        Airline    Source Destination  Total_Stops Additional_Info  Price  \
# 0       IndiGo  Banglore   New Delhi          0.0         No info   3897
# 1    Air India   Kolkata    Banglore          2.0         No info   7662
# 2  Jet Airways     Delhi      Cochin          2.0         No info  13882
# 3       IndiGo   Kolkata    Banglore          1.0         No info   6218
# 4       IndiGo  Banglore   New Delhi          1.0         No info  13302
#
#    Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min  \
# 0    24      3  2019             1           10        22       20
# 1     1      5  2019            13           15         5       50
# 2     9      6  2019             4           25         9       25
# 3    12      5  2019            23           30        18        5
# 4     1      3  2019            21           35        16       50
#
#   Duration_hr Duration_min
# 0           2           50
# 1           7           25
# 2          19          NaN
# ...

# %%
air_df['Duration_min'].unique()
# Out:
# array(['50', '25', nan, '45', '30', '5', '15', '35', '10', '20', '55',
#        '40'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

# %%
air_df['Airline']=labelencoder.fit_transform(air_df['Airline'])
air_df['Source']=labelencoder.fit_transform(air_df['Source'])
air_df['Destination']=labelencoder.fit_transform(air_df['Destination'])
air_df['Additional_Info']=labelencoder.fit_transform(air_df['Additional_Info'])

# %%
air_df.shape
# Out:
# (10683, 15)

# %%
air_df.head(2)
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info  Price  Date  \
# 0        3       0            5          0.0                8   3897    24
# 1        1       3            0          2.0                8   7662     1
#
#    Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min Duration_hr  \
# 0      3  2019             1           10        22       20           2
# 1      5  2019            13           15         5       50           7
#
#   Duration_min
# 0           50
# 1           25
